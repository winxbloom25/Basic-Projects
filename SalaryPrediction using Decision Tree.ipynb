# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
df = pd.read_csv("salaryprediction.csv")

# %%
df.columns
# Out:
# Index(['YearsOfExp', 'NicheSkills', 'Salary'], dtype='object')

# %%
df
# Out:
#     YearsOfExp  NicheSkills  Salary
# 0            5            0       5
# 1            5            0       5
# 2            5            0       5
# 3            5            1      15
# 4            5            1      15
# 5            5            1      15
# 6           10            0      20
# 7           10            0      20
# 8           10            0      20
# 9           10            1      20
# 10          10            1      25
# 11          10            1      25

# %%
dtr = DecisionTreeRegressor(random_state=0)

# %%
X = df[['YearsOfExp', 'NicheSkills']]
y = df.Salary

# %%
model = dtr.fit(X,y)

# %%
feature_names =['YearsOfExp', 'NicheSkills']
plt.figure(figsize=(10,8), dpi=150)
plot_tree(model, feature_names=feature_names)
# Out:
# [Text(0.5, 0.8333333333333334, 'YearsOfExp <= 7.5\nsquared_error = 49.306\nsamples = 12\nvalue = 15.833'),
#  Text(0.25, 0.5, 'NicheSkills <= 0.5\nsquared_error = 25.0\nsamples = 6\nvalue = 10.0'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 0.0\nsamples = 3\nvalue = 15.0'),
#  Text(0.75, 0.5, 'NicheSkills <= 0.5\nsquared_error = 5.556\nsamples = 6\nvalue = 21.667'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 0.0\nsamples = 3\nvalue = 20.0'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 5.556\nsamples = 3\nvalue = 23.333')]

# %%
pd.DataFrame({'features':model.feature_names_in_, 'importance':model.feature_importances_})
# Out:
#       features  importance
# 0   YearsOfExp    0.710145
# 1  NicheSkills    0.289855
